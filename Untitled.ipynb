# %%
import pandas as pd
hr = pd.read_csv('HR_DataSet.csv')
hr.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years    dep  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
hr.shape
# Out:
# (2363, 10)

# %%
hr.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count         2363.000000      2363.000000     2363.000000
# mean             0.475493         0.719073        3.862886
# std              0.271925         0.192578        1.719241
# min              0.090000         0.360000        2.000000
# 25%              0.350000         0.530000        2.000000
# 50%              0.430000         0.770000        4.000000
# 75%              0.750000         0.900000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident         left  \
# count           2363.000000         2363.000000    2363.000000  2363.000000
# mean             205.647905            3.761320       0.067711     0.846382
# std               59.358442            1.021651       0.251302     0.360659
# min               97.000000            2.000000       0.000000     0.000000
# ...

# %%
hr['dep'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
import numpy as np
hr['dep']=np.where(hr['dep'] =='support', 'technical', hr['dep'])
hr['dep']=np.where(hr['dep'] =='IT', 'technical', hr['dep'])

# %%
print(hr['dep'].unique())
# Out:
# ['sales' 'accounting' 'hr' 'technical' 'management' 'product_mng'
#  'marketing' 'RandD']

# %% [markdown]
# # Data Exploration

# %%
hr.groupby('dep').mean()
# Out:
#              satisfaction_level  last_evaluation  number_project  \
# dep
# RandD                  0.471091         0.724818        3.963636
# accounting             0.456822         0.720078        3.875969
# hr                     0.468872         0.687143        3.556391
# management             0.467541         0.735082        3.983607
# marketing              0.491250         0.702656        3.679688
# product_mng            0.496231         0.718692        3.838462
# sales                  0.474799         0.709877        3.745370
# technical              0.475488         0.729443        3.983398
#
#              average_montly_hours  time_spend_company  Work_accident  \
# dep
# RandD                  210.490909            3.800000       0.100000
# accounting             206.325581            3.728682       0.038760
# hr                     196.421053            3.661654       0.045113
# management             205.426230            3.590164       0.065574
# ...

# %%
hr.groupby('salary').mean()
# Out:
#         satisfaction_level  last_evaluation  number_project  \
# salary
# high              0.479825         0.695789        3.824561
# low               0.478475         0.719129        3.838849
# medium            0.470699         0.720437        3.901747
#
#         average_montly_hours  time_spend_company  Work_accident      left  \
# salary
# high              199.192982            3.649123       0.017544  0.842105
# low               204.989209            3.756835       0.064748  0.850360
# medium            207.049127            3.775109       0.075328  0.840611
#
#         promotion_last_5years
# salary
# high                 0.000000
# low                  0.003597
# medium               0.003275

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
pd.crosstab(hr.dep,hr.left).plot(kind='bar')
plt.title('Turnover Frequency for Department')
plt.xlabel('Dep')
plt.ylabel('Frequency of Turnover')
plt.savefig('department_bar_chart')

# %%
table=pd.crosstab(hr.salary, hr.left)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Salary Level vs Turnover')
plt.xlabel('Salary Level')
plt.ylabel('Proportion of Employees')
plt.savefig('salary_bar_chart')

# %%
pd.crosstab(hr.dep, hr.left)
# Out:
# left           0    1
# dep
# RandD         24   86
# accounting    19  110
# hr            20  113
# management     9   52
# marketing     16  112
# product_mng   20  110
# sales         92  556
# technical    163  861

# %%
num_bins = 10

hr.hist(bins=num_bins, figsize=(20,15))
plt.savefig("hr_histogram_plots")
plt.show()

# %%
hr.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years    dep  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
cat_vars=['dep','salary']
for var in cat_vars:
    cat_list='var'+'_'+var
    cat_list = pd.get_dummies(hr[var], prefix=var)
    hr1=hr.join(cat_list)
    hr=hr1

# %%
hr.drop(hr.columns[[8, 9]], axis=1, inplace=True)

# %%
hr.columns.values
# Out:
# array(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident',
#        'left', 'promotion_last_5years', 'dep_RandD', 'dep_accounting',
#        'dep_hr', 'dep_management', 'dep_marketing', 'dep_product_mng',
#        'dep_sales', 'dep_technical', 'salary_high', 'salary_low',
#        'salary_medium'], dtype=object)

# %%
hr_vars=hr.columns.values.tolist()
y=['left']
X=[i for i in hr_vars if i not in y]

# %%
X
# Out:
# ['satisfaction_level',
#  'last_evaluation',
#  'number_project',
#  'average_montly_hours',
#  'time_spend_company',
#  'Work_accident',
#  'promotion_last_5years',
#  'dep_RandD',
#  'dep_accounting',
#  'dep_hr',
#  'dep_management',
#  'dep_marketing',
#  'dep_product_mng',
#  'dep_sales',
#  'dep_technical',
#  'salary_high',
#  'salary_low',
#  'salary_medium']

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

rfe = RFE(model, 10)
rfe = rfe.fit(hr[X], hr[y])
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [ True  True  True False  True  True  True  True False False  True  True
#  False False False  True False False]
# [1 1 1 6 1 1 1 1 3 5 1 1 8 4 7 1 2 9]
# c:\users\daniele ligorio\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\daniele ligorio\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\daniele ligorio\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
cols=['satisfaction_level', 'last_evaluation', 'time_spend_company', 'Work_accident', 'promotion_last_5years', 
      'dep+_RandD', 'dep_hr', 'dep_management', 'salary_high', 'salary_low'] 
X=hr[cols]
y=hr['left']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-b3648d35f566> in <module>
#       1 cols=['satisfaction_level', 'last_evaluation', 'time_spend_company', 'Work_accident', 'promotion_last_5years',
#       2       'dep+_RandD', 'dep_hr', 'dep_management', 'salary_high', 'salary_low']
# ----> 3 X=hr[cols]
#       4 y=hr['left']
#
# c:\users\daniele ligorio\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ...
